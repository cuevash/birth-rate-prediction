# %% [markdown]
# # ETL Phase:
# Where we evaluate and get a better undestanding of the data.

# %% [markdown]
# ## Load the data and explore it :
# Where we evaluate and get a better undestanding of the data.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# import libs
import pandas as pd

# Global
ROOT_DIR_RELATIVE_PATH = "../"

# %% [markdown]
# ### Exploring functions

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", 120)
pd.set_option("display.max_columns", 100)

def explore_csv_file(_file_name: str, first_n: int = 100):
    """Function to explore the data a csv file"""

    return pd.read_csv(_file_name).head(first_n)

# %% [markdown]
# ### World Bank - Gender Statistics files
#
# #### Gender_StatsData.csv

# %%
# !pwd
# Out:
# /Users/hector/code_projects/eternal-rtn/birth-rate-prediction/notebooks

# %%
df = explore_csv_file( f"{ROOT_DIR_RELATIVE_PATH}/data/raw/gender-stats/Gender_StatsData.csv")
df
# Out:
#                    Country Name Country Code  \
# 0   Africa Eastern and Southern          AFE
# 1   Africa Eastern and Southern          AFE
# 2   Africa Eastern and Southern          AFE
# 3   Africa Eastern and Southern          AFE
# 4   Africa Eastern and Southern          AFE
# 5   Africa Eastern and Southern          AFE
# 6   Africa Eastern and Southern          AFE
# 7   Africa Eastern and Southern          AFE
# 8   Africa Eastern and Southern          AFE
# 9   Africa Eastern and Southern          AFE
# 10  Africa Eastern and Southern          AFE
# 11  Africa Eastern and Southern          AFE
# 12  Africa Eastern and Southern          AFE
# 13  Africa Eastern and Southern          AFE
# 14  Africa Eastern and Southern          AFE
# 15  Africa Eastern and Southern          AFE
# 16  Africa Eastern and Southern          AFE
# 17  Africa Eastern and Southern          AFE
# 18  Africa Eastern and Southern          AFE
# 19  Africa Eastern and Southern          AFE
# ...

# %% [markdown]
# ### World Bank - Economics Indicators
#
# #### WDIData.csv

# %%
df = explore_csv_file( f"{ROOT_DIR_RELATIVE_PATH}/data/raw/ids/IDS_ALLCountries_Data.csv")
df
# Out:
#    Country Name Country Code Counterpart-Area Name Counterpart-Area Code  \
# 0   Afghanistan          AFG                 World                   WLD
# 1   Afghanistan          AFG                 World                   WLD
# 2   Afghanistan          AFG                 World                   WLD
# 3   Afghanistan          AFG                 World                   WLD
# 4   Afghanistan          AFG                 World                   WLD
# 5   Afghanistan          AFG                 World                   WLD
# 6   Afghanistan          AFG                 World                   WLD
# 7   Afghanistan          AFG                 World                   WLD
# 8   Afghanistan          AFG                 World                   WLD
# 9   Afghanistan          AFG                 World                   WLD
# 10  Afghanistan          AFG                 World                   WLD
# 11  Afghanistan          AFG                 World                   WLD
# ...

# %% [markdown]
# ### World Bank - Social Indicators
#
# #### IDS_ALLCountries_Data.csv

# %%
df = explore_csv_file( f"{ROOT_DIR_RELATIVE_PATH}/data/raw/wdi/WDIData.csv")
df
# Out:
#                    Country Name Country Code  \
# 0   Africa Eastern and Southern          AFE
# 1   Africa Eastern and Southern          AFE
# 2   Africa Eastern and Southern          AFE
# 3   Africa Eastern and Southern          AFE
# 4   Africa Eastern and Southern          AFE
# 5   Africa Eastern and Southern          AFE
# 6   Africa Eastern and Southern          AFE
# 7   Africa Eastern and Southern          AFE
# 8   Africa Eastern and Southern          AFE
# 9   Africa Eastern and Southern          AFE
# 10  Africa Eastern and Southern          AFE
# 11  Africa Eastern and Southern          AFE
# 12  Africa Eastern and Southern          AFE
# 13  Africa Eastern and Southern          AFE
# 14  Africa Eastern and Southern          AFE
# 15  Africa Eastern and Southern          AFE
# 16  Africa Eastern and Southern          AFE
# 17  Africa Eastern and Southern          AFE
# 18  Africa Eastern and Southern          AFE
# 19  Africa Eastern and Southern          AFE
# ...

# %% [markdown]
# ### Selecting the attributes
#
# After examining the files we choose the next list of attributes as predictor of the fertility rate. It is a combination of education values, macroenomic variables and
